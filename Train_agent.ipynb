# %%
import sys
# !{sys.executable} -m pip install --upgrade git+https://github.com/AndersBjelland/IT3105_Project2.git@dev
# Out:
# ...
#   Cloning https://github.com/AndersBjelland/IT3105_Project2.git (to revision dev) to /private/var/folders/dm/8497wlxs7d34zt6c6wdjfh500000gn/T/pip-req-build-ce662nsc
# ...
#   Created wheel for Project2: filename=Project2-1.0-py3-none-any.whl size=15025 sha256=fcf29d02a7f79c0af980d52c727a2dfdf0bfa25b71e5042ce0998c68f0379d46
#   Stored in directory: /private/var/folders/dm/8497wlxs7d34zt6c6wdjfh500000gn/T/pip-ephem-wheel-cache-1o0yejjf/wheels/b2/24/99/8fa89aec957ae3920f431ef10ca7ed9e2e3743c4e806a2fbf0
# Successfully built Project2
# ...
#   Attempting uninstall: Project2
#     Found existing installation: Project2 1.0
#     Uninstalling Project2-1.0:
#       Successfully uninstalled Project2-1.0
# ...

# %%
# our code
from src import *

# %%
hex = Hex((5,5))
encoder = HexEncoder(padding=2)

actor = Actor(learning_rate=0.001,
             epsilon=0.25,
             end_epsilon=0.05,
             nn_shape=(155,128,25),
             filters=(128, 128, 64),
             kernel_sizes=((5,5),(3,3),(1,1)),
                nn_opt='Adam',
              nn_activation='relu',
              nn_last_activation='softmax',
              nn_loss= 'categorical_crossentropy',
              encoder=encoder
             )
              
            
agent = Agent(actor)

# %%
agent.train_agent(hex, n_episodes=4, n_simulations=10, epochs=10, M=2, file_name="test")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1/10
# 1/1 [==============================] - 1s 637ms/step - loss: 3.2086 - accuracy: 0.1500
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1508 - accuracy: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 0s 14ms/step - loss: 3.0772 - accuracy: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 0s 34ms/step - loss: 3.0201 - accuracy: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 0s 23ms/step - loss: 2.9671 - accuracy: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 40ms/step - loss: 2.9314 - accuracy: 0.0500
# Epoch 7/10
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9085 - accuracy: 0.0500
# Epoch 8/10
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8793 - accuracy: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8518 - accuracy: 0.0500
# Epoch 10/10
# ...

# %%
agent.train_agent(hex, n_episodes=350, n_simulations=500, epochs=10, M=2, file_name="test")
# Out:
#   0%|          | 0/350 [00:12<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f1fb7c0e14ff> in <module>
# ----> 1 agent.train_agent(hex, n_episodes=350, n_simulations=500, epochs=10, M=2, file_name="test")
#
# ~/vscodeProjects/IT3105/Project2/src/agent.py in train_agent(self, env, n_episodes, n_simulations, epochs, M, file_name)
#      45         for i in tqdm(range(n_episodes)):
#      46             # Add new training examples to the replay buffer
# ---> 47             replay_buffer = self.run_episode(env=env, n_simulations=n_simulations) + replay_buffer
#      48             # Only keep the last 5000 steps
#      49             replay_buffer = replay_buffer[:50000]
#
# ~/vscodeProjects/IT3105/Project2/src/agent.py in run_episode(self, env, n_simulations)
#      20
#      21         while env.get_winner() == 0:
# ...

# %%
agent.run_episode(env=hex, n_simulations=10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-0a71ad2e1eda> in <module>
# ----> 1 agent.run_episode(env=hex, n_simulations=10)
#
# ~/vscodeProjects/IT3105/Project2/src/agent.py in run_episode(self, env, n_simulations)
#      20
#      21         while env.get_winner() == 0:
# ---> 22             distribution = mcts.search(n_simulations=n_simulations)
#      23
#      24             # Choose action greedily
#
# ~/vscodeProjects/IT3105/Project2/src/monte_carlo_ts.py in search(self, n_simulations, exploration_bonus, c, update_rate, ax1, ax2, plotting)
#     167
#     168         for _ in range(n_simulations):
# --> 169             self.perform_simulation()
#     170
#     171             if (_+1) % update_rate == 0 and plotting:
#
# ~/vscodeProjects/IT3105/Project2/src/monte_carlo_ts.py in perform_simulation(self)
# ...

# %%
mcts = MCTS(target_policy=actor, env=hex)

# %%
mcts.search(100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-5b2dee2321d3> in <module>
# ----> 1 mcts.search(100)
#
# ~/vscodeProjects/IT3105/Project2/src/monte_carlo_ts.py in search(self, n_simulations, exploration_bonus, c, update_rate, ax1, ax2, plotting)
#     167
#     168         for _ in range(n_simulations):
# --> 169             self.perform_simulation()
#     170
#     171             if (_+1) % update_rate == 0 and plotting:
#
# ~/vscodeProjects/IT3105/Project2/src/monte_carlo_ts.py in perform_simulation(self)
#     156         leaf_node = self._traverse_to_leaf()
#     157         expanded_node = self._expand(leaf_node)
# --> 158         value = self._rollout(expanded_node)
#     159         self._back_prop(expanded_node, value)
#     160
#
# ~/vscodeProjects/IT3105/Project2/src/monte_carlo_ts.py in _rollout(self, node)
#      80
# ...
